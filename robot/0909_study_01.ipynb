# %% [markdown]
# - 하드웨어에 값을 지정할 때는 소프트웨어 수준에서 값을 먼저 확인해 보고 값이 적절한 수치 일 때 하드웨어에 지정하는 과정을 거치는 것이 하드웨어의 이슈를 회피하기 좋음
# - map() 함수를 사용할때는 현재 전달되는 값이 min/max 로 지정한 값 범위안에 들어오는 지 확인하고 범위를 벗어난 다면 전처리를 거쳐 범위 안의 값으로 지정해 주는 과정이 필요
