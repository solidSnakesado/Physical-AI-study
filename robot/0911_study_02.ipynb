# %% [markdown]
# - 적외선 센서가 감지되면(센서 인풋 데이터가 HIGH) 타이머를 작동, 타이머가 5초가 되기 전까지 LED를 점등, 5초가 지나면 LED 끔, HIGH 인 상태에서 추가로 적외선 센서가 감지되면 타이머 리셋
#
# - LED 3개를 각각 1, 3, 6초 주기로 깜박이게 제어
#     - 1초 on, 1초 off
#     - 3초 on, 3초 off
#     - 6초 on, 6초 off
#     - 일단 타이머를 3개를 두고 각각 시간을 체크하여 제어,
#     - 타이머 1개로 진행할 수 있는 방법이 있을 지 고민
