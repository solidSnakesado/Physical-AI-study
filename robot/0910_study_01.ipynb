# %% [markdown]
# - 필요한 기능, 버튼을 누르면 누를 때마다 10도씩 회전, 180도에 이르면 반대 방향으로 10도씩 회전, 0도이 이르면 다시 반대 방향으로 10도씩 회전
# - 버튼 입력 체크 필요 -> 입력 체크 후 모터 회전 필요

# %% [markdown]
# - 조도 센서로 나무를 감지 <- pass
# - 나무가 감지 되었을때 서보 모터를 조작 하여 키보드를 누를 수 있게 처리 <-현재 진행 중
#     - 나무가 감지 된다는 것은 조도 센서의 값이 어두워 지는 구간을 확인 해야 함 최근 n개 구간의 평균은 계산하다가 평균 값보다 일정 수치 이하로 떨어지는 구간의 신호 포착 필요
#         - n은 일단 10개로 지정, 이하의 값이 포착되면 점프 글자 출력
