# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("../data/lenna.bmp")
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(img)

# %% [markdown]
# - 그림이 파란색 필터가 있는 것처럼 표시
# - matplotlib는 rgb 순서로 이미지를 읽는 데 opencv는 bgr 순서로 읽기 때문
# - cvtColor에 COLOR_BGR2RGB를 적용

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread("../data/lenna.bmp", cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap="gray")

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
new_img = cv2.resize(fix_img, (800, 600))
plt.imshow(new_img)

# %%
plt.imshow(cv2.flip(fix_img, 0))

# %%
plt.imshow(cv2.flip(fix_img, 1))

# %%
plt.imshow(cv2.flip(fix_img, -1))

# %%
plt.imshow(img_gray, cmap="gray")

# %%
cv2.imwrite("../data/lenna_gray.jpg", img_gray)
# Out:
# True
